# %% [markdown]
# # Lab 5 Homework
#
# ### <div class="alert alert-block alert-danger"><b>Practice in Birmingham:</b> Temperatures and Actuary Salaries</div>

# %% [markdown]
# Hint: Some helpful functions in R may be: `prop.test()` and `t.test()` for this assignment

# %% [markdown]
# **Part I: Actuary Income**
#
# **Question 1:** You want to estimate the proportion of actuaries in Birmingham earning over \\$100,000 with 90 percent     confidence and a margin of error of 5 percent. Assuming $\hat{p}$ is around .4, calculate the required sample size.
#
# **Question 2:** You hypothesize that less than 50\% of actuaries in Birmingham earn more than \\$100,000 annually. You want to test this hypothesis using the data you collected which was that out of 260 Birmingham actuaries, 115 of them made more than \$100,000 annually.
#
# #### Steps:
# 1. Formulate the hypotheses:
#     - Null hypothesis (H₀): 50\% of actuaries in Birmingham earn more than \\$100,000.
#     - Alternative hypothesis (Hₐ): Less than 50% of actuaries in Birmingham earn more than \\$100,000.
# 2. Use a one-sample proportion test to determine if the observed proportion of actuaries earning over \\$100,000 is significantly less than 50%.

# %% [markdown]
# **Part 2: Birmingham vs. Huntsville Temperatures**
#
# The temperature highs for all 31 days of May 2024 are given here for Birmingham, AL: https://www.accuweather.com/en/us/birmingham/35203/may-weather/346630 and here for Huntsville, AL: https://www.accuweather.com/en/us/huntsville/35801/may-weather/326704?year=2024.
#
#
# **Question 3:** Perform a two-sample t-test to determine if there is a significant difference in the average temperatures between Birmingham and Huntsville in May.
#
# **Question 4:** Calculate the proportion of days in Birmingham and Huntsville where the temperature exceeded 80°F. Perform a two-sample population proportion test to see if there is a significant difference in these proportions.

# %% [markdown]
# Please use the Homework Template to write up your homework assignment.
