# %% [markdown]
# # Edit Homework Name (e.g. Lab 4 Homework)

# %% [markdown]
# **This is a homework assignment template but should be adjusted to meet the setup of each individual assignment (Parts and Questions, etc). Think about your lab homework as a report to someone you work for.
# You want to write it as a clear story/narrative where they can read it from beginning to end
# and understand what your goals were, what results you achieved using coding, and what your conclusions were. This will set you up for success with your Final Project.**
#
# **Note: Be sure to delete this cell (text of code) for your submission.**

# %% [markdown]
# The focus of this assignment was....(fill in what the overarching idea of the assignment was).

# %% [markdown]
# **Question 1**: Explain what you are about to do (what your goal is).

# %%
Do this work using Code here and run the code to achieve an output.

# %% [markdown]
# Then provide your answer for Question 1 here in Markdown.

# %% [markdown]
# **Question 2**: Explain what you are about to do (what your goal is).

# %%
Do this work using Code here and run the code to achieve an output.

# %% [markdown]
# Then provide your answer for Question 2 here in Markdown.
